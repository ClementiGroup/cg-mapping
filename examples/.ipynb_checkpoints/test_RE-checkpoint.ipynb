# %%
import sys

sys.path.insert(0, "../simulation")
sys.path.insert(0, "../methods")

import numpy as np
from ReconstructionErrorClass import RE
from AnalyticalMappingEntropyClass import AME
from SimulationClass import Simulation
from TicaTimescalesClass import TICA
#from _methods_utils import _mapping_combinations
import networkx as nx
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 15

# %matplotlib inline

# %%
traj = np.load('./coords.npy')
print(traj.shape)
# Out:
# (2000, 40, 3)

# %%
RE_model = RE(traj=traj, device='cuda')

# %%
RE_model.train_RE(batch_size=32) # it will take a while
# Out:
# epoch 0 reconstruction 0.344 validation 0.293
# epoch 50 reconstruction 0.116 validation 0.113
# epoch 100 reconstruction 0.077 validation 0.080
# epoch 150 reconstruction 0.074 validation 0.079
# epoch 200 reconstruction 0.055 validation 0.091
# epoch 250 reconstruction 0.042 validation 0.106
# epoch 300 reconstruction 0.036 validation 0.117
# epoch 350 reconstruction 0.030 validation 0.125
# epoch 400 reconstruction 0.029 validation 0.129
# epoch 0 reconstruction 0.283 validation 0.265
# epoch 50 reconstruction 0.108 validation 0.109
# epoch 100 reconstruction 0.077 validation 0.080
# epoch 150 reconstruction 0.075 validation 0.078
# epoch 200 reconstruction 0.058 validation 0.091
# epoch 250 reconstruction 0.044 validation 0.106
# epoch 300 reconstruction 0.036 validation 0.115
# epoch 350 reconstruction 0.032 validation 0.121
# epoch 400 reconstruction 0.029 validation 0.127
# epoch 0 reconstruction 0.329 validation 0.278
# epoch 50 reconstruction 0.114 validation 0.111
# epoch 100 reconstruction 0.078 validation 0.080
# epoch 150 reconstruction 0.075 validation 0.078
# epoch 200 reconstruction 0.058 validation 0.089
# epoch 250 reconstruction 0.044 validation 0.106
# epoch 300 reconstruction 0.038 validation 0.113
# epoch 350 reconstruction 0.034 validation 0.120
# epoch 400 reconstruction 0.030 validation 0.127
# epoch 0 reconstruction 0.332 validation 0.320
# epoch 50 reconstruction 0.116 validation 0.118
# epoch 100 reconstruction 0.078 validation 0.080
# epoch 150 reconstruction 0.075 validation 0.078
# epoch 200 reconstruction 0.056 validation 0.091
# epoch 250 reconstruction 0.043 validation 0.105
# epoch 300 reconstruction 0.038 validation 0.114
# epoch 350 reconstruction 0.033 validation 0.122
# epoch 400 reconstruction 0.030 validation 0.127
# epoch 0 reconstruction 0.304 validation 0.261
# epoch 50 reconstruction 0.111 validation 0.108
# epoch 100 reconstruction 0.078 validation 0.080
# epoch 150 reconstruction 0.076 validation 0.079
# epoch 200 reconstruction 0.055 validation 0.092
# epoch 250 reconstruction 0.046 validation 0.109
# epoch 300 reconstruction 0.035 validation 0.122
# epoch 350 reconstruction 0.031 validation 0.131
# epoch 400 reconstruction 0.029 validation 0.141
# epoch 0 reconstruction 0.274 validation 0.251
# epoch 50 reconstruction 0.110 validation 0.110
# epoch 100 reconstruction 0.078 validation 0.081
# epoch 150 reconstruction 0.076 validation 0.079
# epoch 200 reconstruction 0.059 validation 0.092
# epoch 250 reconstruction 0.048 validation 0.107
# epoch 300 reconstruction 0.039 validation 0.117
# epoch 350 reconstruction 0.034 validation 0.127
# epoch 400 reconstruction 0.032 validation 0.134
# epoch 0 reconstruction 0.305 validation 0.273
# epoch 50 reconstruction 0.114 validation 0.113
# epoch 100 reconstruction 0.078 validation 0.080
# epoch 150 reconstruction 0.075 validation 0.078
# epoch 200 reconstruction 0.058 validation 0.089
# epoch 250 reconstruction 0.043 validation 0.105
# epoch 300 reconstruction 0.037 validation 0.116
# epoch 350 reconstruction 0.032 validation 0.122
# epoch 400 reconstruction 0.028 validation 0.126
# epoch 0 reconstruction 0.347 validation 0.263
# epoch 50 reconstruction 0.119 validation 0.111
# epoch 100 reconstruction 0.077 validation 0.080
# epoch 150 reconstruction 0.075 validation 0.078
# epoch 200 reconstruction 0.054 validation 0.090
# epoch 250 reconstruction 0.043 validation 0.101
# epoch 300 reconstruction 0.037 validation 0.114
# epoch 350 reconstruction 0.033 validation 0.122
# epoch 400 reconstruction 0.029 validation 0.126
# epoch 0 reconstruction 0.271 validation 0.283
# epoch 50 reconstruction 0.111 validation 0.118
# epoch 100 reconstruction 0.078 validation 0.082
# epoch 150 reconstruction 0.076 validation 0.079
# epoch 200 reconstruction 0.055 validation 0.096
# epoch 250 reconstruction 0.041 validation 0.116
# epoch 300 reconstruction 0.035 validation 0.127
# epoch 350 reconstruction 0.031 validation 0.133
# epoch 400 reconstruction 0.029 validation 0.140
# epoch 0 reconstruction 0.307 validation 0.290
# epoch 50 reconstruction 0.114 validation 0.116
# epoch 100 reconstruction 0.078 validation 0.081
# epoch 150 reconstruction 0.075 validation 0.078
# epoch 200 reconstruction 0.058 validation 0.087
# epoch 250 reconstruction 0.048 validation 0.099
# epoch 300 reconstruction 0.040 validation 0.108
# epoch 350 reconstruction 0.035 validation 0.116
# epoch 400 reconstruction 0.031 validation 0.121
# epoch 0 reconstruction 0.283 validation 0.257
# epoch 50 reconstruction 0.110 validation 0.110
# epoch 100 reconstruction 0.078 validation 0.080
# epoch 150 reconstruction 0.076 validation 0.079
# epoch 200 reconstruction 0.056 validation 0.092
# epoch 250 reconstruction 0.044 validation 0.108
# epoch 300 reconstruction 0.035 validation 0.121
# epoch 350 reconstruction 0.032 validation 0.130
# epoch 400 reconstruction 0.029 validation 0.136
# epoch 0 reconstruction 0.313 validation 0.305
# epoch 50 reconstruction 0.114 validation 0.117
# epoch 100 reconstruction 0.077 validation 0.080
# epoch 150 reconstruction 0.075 validation 0.077
# epoch 200 reconstruction 0.055 validation 0.093
# epoch 250 reconstruction 0.041 validation 0.116
# epoch 300 reconstruction 0.034 validation 0.126
# epoch 350 reconstruction 0.030 validation 0.136
# epoch 400 reconstruction 0.027 validation 0.141
# epoch 0 reconstruction 0.306 validation 0.254
# epoch 50 reconstruction 0.112 validation 0.109
# epoch 100 reconstruction 0.077 validation 0.080
# epoch 150 reconstruction 0.075 validation 0.078
# epoch 200 reconstruction 0.055 validation 0.092
# epoch 250 reconstruction 0.041 validation 0.106
# epoch 300 reconstruction 0.035 validation 0.116
# epoch 350 reconstruction 0.031 validation 0.122
# epoch 400 reconstruction 0.027 validation 0.128
# epoch 0 reconstruction 0.279 validation 0.231
# epoch 50 reconstruction 0.110 validation 0.106
# epoch 100 reconstruction 0.078 validation 0.080
# epoch 150 reconstruction 0.075 validation 0.079
# epoch 200 reconstruction 0.056 validation 0.090
# epoch 250 reconstruction 0.041 validation 0.110
# epoch 300 reconstruction 0.034 validation 0.121
# epoch 350 reconstruction 0.031 validation 0.130
# epoch 400 reconstruction 0.028 validation 0.135
# epoch 0 reconstruction 0.317 validation 0.299
# epoch 50 reconstruction 0.116 validation 0.117
# epoch 100 reconstruction 0.078 validation 0.081
# epoch 150 reconstruction 0.075 validation 0.078
# epoch 200 reconstruction 0.055 validation 0.091
# epoch 250 reconstruction 0.042 validation 0.105
# epoch 300 reconstruction 0.036 validation 0.114
# epoch 350 reconstruction 0.033 validation 0.119
# epoch 400 reconstruction 0.030 validation 0.125
# epoch 0 reconstruction 0.316 validation 0.283
# epoch 50 reconstruction 0.114 validation 0.112
# epoch 100 reconstruction 0.077 validation 0.080
# epoch 150 reconstruction 0.075 validation 0.077
# epoch 200 reconstruction 0.054 validation 0.092
# epoch 250 reconstruction 0.041 validation 0.107
# epoch 300 reconstruction 0.035 validation 0.118
# epoch 350 reconstruction 0.030 validation 0.124
# epoch 400 reconstruction 0.027 validation 0.131
# epoch 0 reconstruction 0.307 validation 0.260
# epoch 50 reconstruction 0.112 validation 0.109
# epoch 100 reconstruction 0.077 validation 0.080
# epoch 150 reconstruction 0.075 validation 0.079
# epoch 200 reconstruction 0.055 validation 0.092
# epoch 250 reconstruction 0.042 validation 0.106
# epoch 300 reconstruction 0.037 validation 0.117
# epoch 350 reconstruction 0.032 validation 0.124
# epoch 400 reconstruction 0.027 validation 0.131
# epoch 0 reconstruction 0.305 validation 0.262
# epoch 50 reconstruction 0.112 validation 0.109
# epoch 100 reconstruction 0.078 validation 0.079
# epoch 150 reconstruction 0.075 validation 0.078
# epoch 200 reconstruction 0.055 validation 0.091
# epoch 250 reconstruction 0.042 validation 0.108
# epoch 300 reconstruction 0.035 validation 0.121
# epoch 350 reconstruction 0.030 validation 0.131
# epoch 400 reconstruction 0.027 validation 0.136
# epoch 0 reconstruction 0.335 validation 0.267
# epoch 50 reconstruction 0.117 validation 0.110
# epoch 100 reconstruction 0.077 validation 0.079
# epoch 150 reconstruction 0.074 validation 0.077
# epoch 200 reconstruction 0.058 validation 0.087
# epoch 250 reconstruction 0.042 validation 0.104
# epoch 300 reconstruction 0.036 validation 0.113
# epoch 350 reconstruction 0.032 validation 0.120
# epoch 400 reconstruction 0.028 validation 0.126
# epoch 0 reconstruction 0.331 validation 0.287
# epoch 50 reconstruction 0.116 validation 0.114
# epoch 100 reconstruction 0.076 validation 0.080
# epoch 150 reconstruction 0.073 validation 0.077
# epoch 200 reconstruction 0.054 validation 0.089
# epoch 250 reconstruction 0.042 validation 0.104
# epoch 300 reconstruction 0.033 validation 0.115
# epoch 350 reconstruction 0.029 validation 0.125
# epoch 400 reconstruction 0.026 validation 0.129
# epoch 0 reconstruction 0.366 validation 0.310
# epoch 50 reconstruction 0.121 validation 0.119
# epoch 100 reconstruction 0.076 validation 0.079
# epoch 150 reconstruction 0.073 validation 0.076
# epoch 200 reconstruction 0.054 validation 0.087
# epoch 250 reconstruction 0.039 validation 0.102
# epoch 300 reconstruction 0.033 validation 0.112
# epoch 350 reconstruction 0.031 validation 0.117
# epoch 400 reconstruction 0.027 validation 0.125
# epoch 0 reconstruction 0.355 validation 0.274
# epoch 50 reconstruction 0.120 validation 0.112
# epoch 100 reconstruction 0.077 validation 0.078
# epoch 150 reconstruction 0.073 validation 0.076
# epoch 200 reconstruction 0.054 validation 0.091
# epoch 250 reconstruction 0.041 validation 0.103
# epoch 300 reconstruction 0.035 validation 0.115
# epoch 350 reconstruction 0.031 validation 0.123
# epoch 400 reconstruction 0.028 validation 0.129
# epoch 0 reconstruction 0.308 validation 0.253
# epoch 50 reconstruction 0.115 validation 0.110
# epoch 100 reconstruction 0.078 validation 0.080
# epoch 150 reconstruction 0.075 validation 0.078
# epoch 200 reconstruction 0.056 validation 0.092
# epoch 250 reconstruction 0.043 validation 0.108
# epoch 300 reconstruction 0.036 validation 0.119
# epoch 350 reconstruction 0.032 validation 0.126
# epoch 400 reconstruction 0.030 validation 0.130
# epoch 0 reconstruction 0.290 validation 0.246
# epoch 50 reconstruction 0.110 validation 0.107
# epoch 100 reconstruction 0.077 validation 0.079
# epoch 150 reconstruction 0.075 validation 0.078
# epoch 200 reconstruction 0.056 validation 0.089
# epoch 250 reconstruction 0.042 validation 0.103
# epoch 300 reconstruction 0.035 validation 0.114
# epoch 350 reconstruction 0.032 validation 0.121
# epoch 400 reconstruction 0.029 validation 0.129
# epoch 0 reconstruction 0.297 validation 0.259
# epoch 50 reconstruction 0.110 validation 0.108
# epoch 100 reconstruction 0.077 validation 0.078
# epoch 150 reconstruction 0.075 validation 0.077
# epoch 200 reconstruction 0.059 validation 0.085
# epoch 250 reconstruction 0.045 validation 0.099
# epoch 300 reconstruction 0.038 validation 0.111
# epoch 350 reconstruction 0.033 validation 0.117
# epoch 400 reconstruction 0.030 validation 0.122
# epoch 0 reconstruction 0.288 validation 0.252
# epoch 50 reconstruction 0.112 validation 0.112
# epoch 100 reconstruction 0.078 validation 0.081
# epoch 150 reconstruction 0.075 validation 0.079
# epoch 200 reconstruction 0.057 validation 0.089
# epoch 250 reconstruction 0.044 validation 0.106
# epoch 300 reconstruction 0.036 validation 0.116
# epoch 350 reconstruction 0.032 validation 0.126
# epoch 400 reconstruction 0.029 validation 0.133
# epoch 0 reconstruction 0.270 validation 0.251
# epoch 50 reconstruction 0.111 validation 0.111
# epoch 100 reconstruction 0.078 validation 0.081
# epoch 150 reconstruction 0.076 validation 0.080
# epoch 200 reconstruction 0.057 validation 0.093
# epoch 250 reconstruction 0.043 validation 0.110
# epoch 300 reconstruction 0.039 validation 0.117
# epoch 350 reconstruction 0.034 validation 0.127
# epoch 400 reconstruction 0.030 validation 0.133
# epoch 0 reconstruction 0.275 validation 0.242
# epoch 50 reconstruction 0.111 validation 0.109
# epoch 100 reconstruction 0.078 validation 0.081
# epoch 150 reconstruction 0.076 validation 0.079
# epoch 200 reconstruction 0.061 validation 0.088
# epoch 250 reconstruction 0.048 validation 0.102
# epoch 300 reconstruction 0.040 validation 0.112
# epoch 350 reconstruction 0.034 validation 0.120
# epoch 400 reconstruction 0.032 validation 0.124
# epoch 0 reconstruction 0.301 validation 0.279
# epoch 50 reconstruction 0.112 validation 0.113
# epoch 100 reconstruction 0.077 validation 0.080
# epoch 150 reconstruction 0.075 validation 0.078
# epoch 200 reconstruction 0.057 validation 0.091
# epoch 250 reconstruction 0.044 validation 0.105
# epoch 300 reconstruction 0.035 validation 0.117
# epoch 350 reconstruction 0.032 validation 0.122
# epoch 400 reconstruction 0.030 validation 0.129
# epoch 0 reconstruction 0.290 validation 0.248
# epoch 50 reconstruction 0.112 validation 0.108
# epoch 100 reconstruction 0.078 validation 0.080
# epoch 150 reconstruction 0.075 validation 0.079
# epoch 200 reconstruction 0.055 validation 0.089
# epoch 250 reconstruction 0.040 validation 0.102
# epoch 300 reconstruction 0.033 validation 0.113
# epoch 350 reconstruction 0.031 validation 0.120
# epoch 400 reconstruction 0.026 validation 0.124
# epoch 0 reconstruction 0.279 validation 0.251
# epoch 50 reconstruction 0.110 validation 0.109
# epoch 100 reconstruction 0.077 validation 0.080
# epoch 150 reconstruction 0.075 validation 0.078
# epoch 200 reconstruction 0.055 validation 0.092
# epoch 250 reconstruction 0.041 validation 0.108
# epoch 300 reconstruction 0.034 validation 0.119
# epoch 350 reconstruction 0.030 validation 0.127
# epoch 400 reconstruction 0.027 validation 0.132
# epoch 0 reconstruction 0.279 validation 0.263
# epoch 50 reconstruction 0.110 validation 0.112
# epoch 100 reconstruction 0.077 validation 0.079
# epoch 150 reconstruction 0.074 validation 0.077
# epoch 200 reconstruction 0.057 validation 0.086
# epoch 250 reconstruction 0.044 validation 0.102
# epoch 300 reconstruction 0.037 validation 0.111
# epoch 350 reconstruction 0.033 validation 0.117
# epoch 400 reconstruction 0.031 validation 0.123
# epoch 0 reconstruction 0.314 validation 0.310
# epoch 50 reconstruction 0.116 validation 0.119
# epoch 100 reconstruction 0.076 validation 0.080
# epoch 150 reconstruction 0.073 validation 0.077
# epoch 200 reconstruction 0.053 validation 0.093
# epoch 250 reconstruction 0.040 validation 0.108
# epoch 300 reconstruction 0.033 validation 0.118
# epoch 350 reconstruction 0.029 validation 0.126
# epoch 400 reconstruction 0.026 validation 0.131
# epoch 0 reconstruction 0.278 validation 0.294
# epoch 50 reconstruction 0.111 validation 0.117
# epoch 100 reconstruction 0.076 validation 0.080
# epoch 150 reconstruction 0.074 validation 0.077
# epoch 200 reconstruction 0.055 validation 0.090
# epoch 250 reconstruction 0.040 validation 0.109
# epoch 300 reconstruction 0.034 validation 0.119
# epoch 350 reconstruction 0.030 validation 0.127
# epoch 400 reconstruction 0.029 validation 0.132
# epoch 0 reconstruction 0.295 validation 0.295
# epoch 50 reconstruction 0.112 validation 0.115
# epoch 100 reconstruction 0.076 validation 0.079
# epoch 150 reconstruction 0.074 validation 0.077
# epoch 200 reconstruction 0.054 validation 0.092
# epoch 250 reconstruction 0.042 validation 0.109
# epoch 300 reconstruction 0.037 validation 0.120
# epoch 350 reconstruction 0.033 validation 0.130
# epoch 400 reconstruction 0.030 validation 0.136
# epoch 0 reconstruction 0.331 validation 0.339
# epoch 50 reconstruction 0.115 validation 0.119
# epoch 100 reconstruction 0.075 validation 0.078
# epoch 150 reconstruction 0.072 validation 0.075
# epoch 200 reconstruction 0.053 validation 0.089
# epoch 250 reconstruction 0.041 validation 0.103
# epoch 300 reconstruction 0.034 validation 0.112
# epoch 350 reconstruction 0.031 validation 0.118
# epoch 400 reconstruction 0.029 validation 0.125
# epoch 0 reconstruction 0.344 validation 0.370
# epoch 50 reconstruction 0.124 validation 0.133
# epoch 100 reconstruction 0.077 validation 0.080
# epoch 150 reconstruction 0.072 validation 0.074
# epoch 200 reconstruction 0.053 validation 0.087
# epoch 250 reconstruction 0.041 validation 0.104
# epoch 300 reconstruction 0.033 validation 0.115
# epoch 350 reconstruction 0.030 validation 0.121
# epoch 400 reconstruction 0.027 validation 0.128
# epoch 0 reconstruction 0.358 validation 0.308
# epoch 50 reconstruction 0.120 validation 0.117
# epoch 100 reconstruction 0.075 validation 0.078
# epoch 150 reconstruction 0.071 validation 0.074
# epoch 200 reconstruction 0.051 validation 0.088
# epoch 250 reconstruction 0.038 validation 0.105
# epoch 300 reconstruction 0.033 validation 0.114
# epoch 350 reconstruction 0.029 validation 0.124
# epoch 400 reconstruction 0.027 validation 0.129
# epoch 0 reconstruction 0.359 validation 0.338
# epoch 50 reconstruction 0.121 validation 0.121
# epoch 100 reconstruction 0.076 validation 0.078
# epoch 150 reconstruction 0.072 validation 0.075
# epoch 200 reconstruction 0.056 validation 0.086
# epoch 250 reconstruction 0.042 validation 0.099
# epoch 300 reconstruction 0.036 validation 0.110
# epoch 350 reconstruction 0.031 validation 0.119
# epoch 400 reconstruction 0.030 validation 0.124
# epoch 0 reconstruction 0.235 validation 0.202
# epoch 50 reconstruction 0.102 validation 0.100
# epoch 100 reconstruction 0.078 validation 0.081
# epoch 150 reconstruction 0.076 validation 0.080
# epoch 200 reconstruction 0.057 validation 0.091
# epoch 250 reconstruction 0.043 validation 0.106
# epoch 300 reconstruction 0.036 validation 0.117
# epoch 350 reconstruction 0.032 validation 0.125
# epoch 400 reconstruction 0.030 validation 0.129
# epoch 0 reconstruction 0.255 validation 0.225
# epoch 50 reconstruction 0.104 validation 0.103
# epoch 100 reconstruction 0.078 validation 0.081
# epoch 150 reconstruction 0.076 validation 0.080
# epoch 200 reconstruction 0.056 validation 0.092
# epoch 250 reconstruction 0.043 validation 0.107
# epoch 300 reconstruction 0.035 validation 0.115
# epoch 350 reconstruction 0.032 validation 0.121
# epoch 400 reconstruction 0.029 validation 0.126
# epoch 0 reconstruction 0.239 validation 0.231
# epoch 50 reconstruction 0.099 validation 0.101
# epoch 100 reconstruction 0.077 validation 0.080
# epoch 150 reconstruction 0.076 validation 0.080
# epoch 200 reconstruction 0.057 validation 0.095
# epoch 250 reconstruction 0.042 validation 0.113
# epoch 300 reconstruction 0.034 validation 0.124
# epoch 350 reconstruction 0.030 validation 0.130
# epoch 400 reconstruction 0.026 validation 0.140
# epoch 0 reconstruction 0.219 validation 0.211
# epoch 50 reconstruction 0.099 validation 0.100
# epoch 100 reconstruction 0.078 validation 0.081
# epoch 150 reconstruction 0.077 validation 0.081
# epoch 200 reconstruction 0.058 validation 0.091
# epoch 250 reconstruction 0.045 validation 0.106
# epoch 300 reconstruction 0.037 validation 0.117
# epoch 350 reconstruction 0.034 validation 0.125
# epoch 400 reconstruction 0.032 validation 0.131
# epoch 0 reconstruction 0.208 validation 0.192
# epoch 50 reconstruction 0.098 validation 0.098
# epoch 100 reconstruction 0.078 validation 0.081
# epoch 150 reconstruction 0.077 validation 0.081
# epoch 200 reconstruction 0.058 validation 0.093
# epoch 250 reconstruction 0.044 validation 0.108
# epoch 300 reconstruction 0.036 validation 0.121
# epoch 350 reconstruction 0.032 validation 0.128
# epoch 400 reconstruction 0.030 validation 0.135
# epoch 0 reconstruction 0.238 validation 0.220
# epoch 50 reconstruction 0.103 validation 0.104
# epoch 100 reconstruction 0.078 validation 0.081
# epoch 150 reconstruction 0.077 validation 0.082
# epoch 200 reconstruction 0.058 validation 0.094
# epoch 250 reconstruction 0.044 validation 0.107
# epoch 300 reconstruction 0.038 validation 0.117
# epoch 350 reconstruction 0.033 validation 0.123
# epoch 400 reconstruction 0.030 validation 0.130
# epoch 0 reconstruction 0.259 validation 0.234
# epoch 50 reconstruction 0.106 validation 0.105
# epoch 100 reconstruction 0.077 validation 0.081
# epoch 150 reconstruction 0.076 validation 0.080
# epoch 200 reconstruction 0.055 validation 0.091
# epoch 250 reconstruction 0.044 validation 0.102
# epoch 300 reconstruction 0.039 validation 0.113
# epoch 350 reconstruction 0.033 validation 0.119
# epoch 400 reconstruction 0.031 validation 0.125
# epoch 0 reconstruction 0.219 validation 0.228
# epoch 50 reconstruction 0.100 validation 0.103
# epoch 100 reconstruction 0.078 validation 0.081
# epoch 150 reconstruction 0.077 validation 0.081
# epoch 200 reconstruction 0.061 validation 0.091
# epoch 250 reconstruction 0.047 validation 0.106
# epoch 300 reconstruction 0.043 validation 0.117
# epoch 350 reconstruction 0.038 validation 0.121
# epoch 400 reconstruction 0.034 validation 0.128
# epoch 0 reconstruction 0.241 validation 0.234
# epoch 50 reconstruction 0.104 validation 0.106
# epoch 100 reconstruction 0.078 validation 0.081
# epoch 150 reconstruction 0.076 validation 0.080
# epoch 200 reconstruction 0.059 validation 0.092
# epoch 250 reconstruction 0.044 validation 0.105
# epoch 300 reconstruction 0.037 validation 0.115
# epoch 350 reconstruction 0.033 validation 0.124
# epoch 400 reconstruction 0.029 validation 0.128
# epoch 0 reconstruction 0.230 validation 0.197
# epoch 50 reconstruction 0.103 validation 0.101
# epoch 100 reconstruction 0.078 validation 0.081
# epoch 150 reconstruction 0.077 validation 0.081
# epoch 200 reconstruction 0.060 validation 0.092
# epoch 250 reconstruction 0.044 validation 0.106
# epoch 300 reconstruction 0.037 validation 0.118
# epoch 350 reconstruction 0.032 validation 0.124
# epoch 400 reconstruction 0.031 validation 0.129
# epoch 0 reconstruction 0.244 validation 0.246
# epoch 50 reconstruction 0.102 validation 0.106
# epoch 100 reconstruction 0.077 validation 0.080
# epoch 150 reconstruction 0.076 validation 0.079
# epoch 200 reconstruction 0.057 validation 0.091
# epoch 250 reconstruction 0.042 validation 0.108
# epoch 300 reconstruction 0.035 validation 0.119
# epoch 350 reconstruction 0.032 validation 0.127
# epoch 400 reconstruction 0.028 validation 0.134
# epoch 0 reconstruction 0.251 validation 0.238
# epoch 50 reconstruction 0.104 validation 0.105
# epoch 100 reconstruction 0.078 validation 0.081
# epoch 150 reconstruction 0.077 validation 0.081
# epoch 200 reconstruction 0.058 validation 0.090
# epoch 250 reconstruction 0.043 validation 0.106
# epoch 300 reconstruction 0.036 validation 0.117
# epoch 350 reconstruction 0.031 validation 0.126
# epoch 400 reconstruction 0.029 validation 0.132
# epoch 0 reconstruction 0.222 validation 0.210
# epoch 50 reconstruction 0.099 validation 0.100
# epoch 100 reconstruction 0.078 validation 0.081
# epoch 150 reconstruction 0.077 validation 0.081
# epoch 200 reconstruction 0.061 validation 0.086
# epoch 250 reconstruction 0.049 validation 0.097
# epoch 300 reconstruction 0.044 validation 0.103
# epoch 350 reconstruction 0.039 validation 0.110
# epoch 400 reconstruction 0.037 validation 0.116
# epoch 0 reconstruction 0.238 validation 0.235
# epoch 50 reconstruction 0.102 validation 0.104
# epoch 100 reconstruction 0.077 validation 0.081
# epoch 150 reconstruction 0.076 validation 0.081
# epoch 200 reconstruction 0.056 validation 0.092
# epoch 250 reconstruction 0.043 validation 0.106
# epoch 300 reconstruction 0.035 validation 0.118
# epoch 350 reconstruction 0.033 validation 0.129
# epoch 400 reconstruction 0.028 validation 0.133
# epoch 0 reconstruction 0.263 validation 0.222
# epoch 50 reconstruction 0.104 validation 0.103
# epoch 100 reconstruction 0.077 validation 0.081
# epoch 150 reconstruction 0.076 validation 0.080
# epoch 200 reconstruction 0.057 validation 0.091
# epoch 250 reconstruction 0.043 validation 0.105
# epoch 300 reconstruction 0.037 validation 0.116
# epoch 350 reconstruction 0.033 validation 0.123
# epoch 400 reconstruction 0.029 validation 0.130
# epoch 0 reconstruction 0.240 validation 0.201
# epoch 50 reconstruction 0.100 validation 0.098
# epoch 100 reconstruction 0.077 validation 0.081
# epoch 150 reconstruction 0.076 validation 0.081
# epoch 200 reconstruction 0.057 validation 0.092
# epoch 250 reconstruction 0.044 validation 0.106
# epoch 300 reconstruction 0.038 validation 0.115
# epoch 350 reconstruction 0.034 validation 0.122
# epoch 400 reconstruction 0.031 validation 0.128
# epoch 0 reconstruction 0.231 validation 0.219
# epoch 50 reconstruction 0.099 validation 0.100
# epoch 100 reconstruction 0.077 validation 0.080
# epoch 150 reconstruction 0.076 validation 0.080
# epoch 200 reconstruction 0.057 validation 0.092
# epoch 250 reconstruction 0.044 validation 0.107
# epoch 300 reconstruction 0.037 validation 0.119
# epoch 350 reconstruction 0.033 validation 0.128
# epoch 400 reconstruction 0.031 validation 0.134
# epoch 0 reconstruction 0.254 validation 0.234
# epoch 50 reconstruction 0.104 validation 0.103
# epoch 100 reconstruction 0.077 validation 0.080
# epoch 150 reconstruction 0.075 validation 0.079
# epoch 200 reconstruction 0.056 validation 0.090
# epoch 250 reconstruction 0.043 validation 0.106
# epoch 300 reconstruction 0.035 validation 0.115
# epoch 350 reconstruction 0.032 validation 0.124
# epoch 400 reconstruction 0.029 validation 0.129
# epoch 0 reconstruction 0.285 validation 0.257
# epoch 50 reconstruction 0.109 validation 0.108
# epoch 100 reconstruction 0.077 validation 0.081
# epoch 150 reconstruction 0.075 validation 0.079
# epoch 200 reconstruction 0.054 validation 0.090
# epoch 250 reconstruction 0.041 validation 0.105
# epoch 300 reconstruction 0.035 validation 0.116
# epoch 350 reconstruction 0.031 validation 0.124
# epoch 400 reconstruction 0.027 validation 0.129
# epoch 0 reconstruction 0.283 validation 0.291
# epoch 50 reconstruction 0.112 validation 0.116
# epoch 100 reconstruction 0.077 validation 0.081
# epoch 150 reconstruction 0.074 validation 0.078
# epoch 200 reconstruction 0.057 validation 0.088
# epoch 250 reconstruction 0.043 validation 0.103
# epoch 300 reconstruction 0.036 validation 0.113
# epoch 350 reconstruction 0.030 validation 0.122
# epoch 400 reconstruction 0.028 validation 0.127
# epoch 0 reconstruction 0.308 validation 0.278
# epoch 50 reconstruction 0.115 validation 0.114
# epoch 100 reconstruction 0.078 validation 0.081
# epoch 150 reconstruction 0.075 validation 0.078
# epoch 200 reconstruction 0.057 validation 0.090
# epoch 250 reconstruction 0.043 validation 0.106
# epoch 300 reconstruction 0.037 validation 0.115
# epoch 350 reconstruction 0.033 validation 0.123
# epoch 400 reconstruction 0.030 validation 0.128
# epoch 0 reconstruction 0.226 validation 0.210
# epoch 50 reconstruction 0.102 validation 0.103
# epoch 100 reconstruction 0.078 validation 0.081
# epoch 150 reconstruction 0.076 validation 0.080
# epoch 200 reconstruction 0.058 validation 0.089
# epoch 250 reconstruction 0.043 validation 0.104
# epoch 300 reconstruction 0.036 validation 0.113
# epoch 350 reconstruction 0.032 validation 0.120
# epoch 400 reconstruction 0.030 validation 0.126
# epoch 0 reconstruction 0.221 validation 0.198
# epoch 50 reconstruction 0.099 validation 0.099
# epoch 100 reconstruction 0.077 validation 0.081
# epoch 150 reconstruction 0.077 validation 0.080
# epoch 200 reconstruction 0.058 validation 0.092
# epoch 250 reconstruction 0.045 validation 0.105
# epoch 300 reconstruction 0.038 validation 0.114
# epoch 350 reconstruction 0.035 validation 0.118
# epoch 400 reconstruction 0.032 validation 0.125
# epoch 0 reconstruction 0.243 validation 0.214
# epoch 50 reconstruction 0.101 validation 0.100
# epoch 100 reconstruction 0.077 validation 0.080
# epoch 150 reconstruction 0.076 validation 0.080
# epoch 200 reconstruction 0.057 validation 0.091
# epoch 250 reconstruction 0.043 validation 0.106
# epoch 300 reconstruction 0.038 validation 0.115
# epoch 350 reconstruction 0.032 validation 0.125
# epoch 400 reconstruction 0.031 validation 0.129
# epoch 0 reconstruction 0.215 validation 0.201
# epoch 50 reconstruction 0.100 validation 0.101
# epoch 100 reconstruction 0.078 validation 0.081
# epoch 150 reconstruction 0.076 validation 0.080
# epoch 200 reconstruction 0.057 validation 0.093
# epoch 250 reconstruction 0.043 validation 0.108
# epoch 300 reconstruction 0.036 validation 0.119
# epoch 350 reconstruction 0.032 validation 0.126
# epoch 400 reconstruction 0.030 validation 0.133
# epoch 0 reconstruction 0.211 validation 0.188
# epoch 50 reconstruction 0.100 validation 0.099
# epoch 100 reconstruction 0.078 validation 0.081
# epoch 150 reconstruction 0.077 validation 0.081
# epoch 200 reconstruction 0.060 validation 0.091
# epoch 250 reconstruction 0.047 validation 0.104
# epoch 300 reconstruction 0.041 validation 0.113
# epoch 350 reconstruction 0.035 validation 0.120
# epoch 400 reconstruction 0.032 validation 0.127
# epoch 0 reconstruction 0.220 validation 0.199
# epoch 50 reconstruction 0.102 validation 0.101
# epoch 100 reconstruction 0.078 validation 0.081
# epoch 150 reconstruction 0.077 validation 0.081
# epoch 200 reconstruction 0.059 validation 0.092
# epoch 250 reconstruction 0.043 validation 0.108
# epoch 300 reconstruction 0.037 validation 0.117
# epoch 350 reconstruction 0.032 validation 0.124
# epoch 400 reconstruction 0.031 validation 0.129
# epoch 0 reconstruction 0.228 validation 0.202
# epoch 50 reconstruction 0.101 validation 0.100
# epoch 100 reconstruction 0.077 validation 0.081
# epoch 150 reconstruction 0.076 validation 0.080
# epoch 200 reconstruction 0.057 validation 0.093
# epoch 250 reconstruction 0.043 validation 0.109
# epoch 300 reconstruction 0.034 validation 0.119
# epoch 350 reconstruction 0.031 validation 0.126
# epoch 400 reconstruction 0.029 validation 0.133
# epoch 0 reconstruction 0.232 validation 0.218
# epoch 50 reconstruction 0.102 validation 0.102
# epoch 100 reconstruction 0.078 validation 0.081
# epoch 150 reconstruction 0.076 validation 0.080
# epoch 200 reconstruction 0.056 validation 0.092
# epoch 250 reconstruction 0.042 validation 0.105
# epoch 300 reconstruction 0.035 validation 0.116
# epoch 350 reconstruction 0.029 validation 0.123
# epoch 400 reconstruction 0.027 validation 0.127
# epoch 0 reconstruction 0.215 validation 0.207
# epoch 50 reconstruction 0.100 validation 0.101
# epoch 100 reconstruction 0.078 validation 0.081
# epoch 150 reconstruction 0.077 validation 0.081
# epoch 200 reconstruction 0.056 validation 0.092
# epoch 250 reconstruction 0.043 validation 0.106
# epoch 300 reconstruction 0.037 validation 0.114
# epoch 350 reconstruction 0.033 validation 0.122
# epoch 400 reconstruction 0.029 validation 0.129
# epoch 0 reconstruction 0.226 validation 0.227
# epoch 50 reconstruction 0.101 validation 0.104
# epoch 100 reconstruction 0.077 validation 0.080
# epoch 150 reconstruction 0.076 validation 0.079
# epoch 200 reconstruction 0.057 validation 0.090
# epoch 250 reconstruction 0.043 validation 0.107
# epoch 300 reconstruction 0.037 validation 0.118
# epoch 350 reconstruction 0.033 validation 0.125
# epoch 400 reconstruction 0.030 validation 0.130
# epoch 0 reconstruction 0.242 validation 0.244
# epoch 50 reconstruction 0.105 validation 0.107
# epoch 100 reconstruction 0.077 validation 0.080
# epoch 150 reconstruction 0.075 validation 0.079
# epoch 200 reconstruction 0.055 validation 0.089
# epoch 250 reconstruction 0.042 validation 0.102
# epoch 300 reconstruction 0.035 validation 0.114
# epoch 350 reconstruction 0.030 validation 0.120
# epoch 400 reconstruction 0.027 validation 0.126
# epoch 0 reconstruction 0.220 validation 0.261
# epoch 50 reconstruction 0.101 validation 0.112
# epoch 100 reconstruction 0.077 validation 0.081
# epoch 150 reconstruction 0.075 validation 0.078
# epoch 200 reconstruction 0.053 validation 0.089
# epoch 250 reconstruction 0.041 validation 0.106
# epoch 300 reconstruction 0.033 validation 0.114
# epoch 350 reconstruction 0.029 validation 0.123
# epoch 400 reconstruction 0.027 validation 0.128
# epoch 0 reconstruction 0.239 validation 0.214
# epoch 50 reconstruction 0.102 validation 0.101
# epoch 100 reconstruction 0.076 validation 0.079
# epoch 150 reconstruction 0.075 validation 0.078
# epoch 200 reconstruction 0.055 validation 0.095
# epoch 250 reconstruction 0.040 validation 0.112
# epoch 300 reconstruction 0.035 validation 0.125
# epoch 350 reconstruction 0.029 validation 0.135
# epoch 400 reconstruction 0.025 validation 0.139
# epoch 0 reconstruction 0.285 validation 0.282
# epoch 50 reconstruction 0.107 validation 0.109
# epoch 100 reconstruction 0.076 validation 0.078
# epoch 150 reconstruction 0.074 validation 0.077
# epoch 200 reconstruction 0.056 validation 0.090
# epoch 250 reconstruction 0.043 validation 0.104
# epoch 300 reconstruction 0.037 validation 0.116
# epoch 350 reconstruction 0.032 validation 0.124
# epoch 400 reconstruction 0.030 validation 0.129
# epoch 0 reconstruction 0.288 validation 0.317
# epoch 50 reconstruction 0.112 validation 0.120
# epoch 100 reconstruction 0.076 validation 0.080
# epoch 150 reconstruction 0.074 validation 0.077
# epoch 200 reconstruction 0.054 validation 0.086
# epoch 250 reconstruction 0.040 validation 0.103
# epoch 300 reconstruction 0.033 validation 0.113
# epoch 350 reconstruction 0.030 validation 0.119
# epoch 400 reconstruction 0.027 validation 0.125
# epoch 0 reconstruction 0.290 validation 0.297
# epoch 50 reconstruction 0.111 validation 0.115
# epoch 100 reconstruction 0.076 validation 0.079
# epoch 150 reconstruction 0.073 validation 0.076
# epoch 200 reconstruction 0.053 validation 0.090
# epoch 250 reconstruction 0.041 validation 0.106
# epoch 300 reconstruction 0.035 validation 0.117
# epoch 350 reconstruction 0.031 validation 0.124
# epoch 400 reconstruction 0.029 validation 0.129
# epoch 0 reconstruction 0.277 validation 0.300
# epoch 50 reconstruction 0.107 validation 0.112
# epoch 100 reconstruction 0.075 validation 0.078
# epoch 150 reconstruction 0.073 validation 0.076
# epoch 200 reconstruction 0.054 validation 0.091
# epoch 250 reconstruction 0.042 validation 0.106
# epoch 300 reconstruction 0.034 validation 0.121
# epoch 350 reconstruction 0.032 validation 0.126
# epoch 400 reconstruction 0.028 validation 0.133
# epoch 0 reconstruction 0.209 validation 0.198
# epoch 50 reconstruction 0.098 validation 0.099
# epoch 100 reconstruction 0.078 validation 0.081
# epoch 150 reconstruction 0.077 validation 0.080
# epoch 200 reconstruction 0.059 validation 0.088
# epoch 250 reconstruction 0.046 validation 0.102
# epoch 300 reconstruction 0.039 validation 0.113
# epoch 350 reconstruction 0.034 validation 0.119
# epoch 400 reconstruction 0.031 validation 0.124
# epoch 0 reconstruction 0.209 validation 0.249
# epoch 50 reconstruction 0.098 validation 0.107
# epoch 100 reconstruction 0.078 validation 0.081
# epoch 150 reconstruction 0.077 validation 0.079
# epoch 200 reconstruction 0.058 validation 0.093
# epoch 250 reconstruction 0.043 validation 0.106
# epoch 300 reconstruction 0.036 validation 0.119
# epoch 350 reconstruction 0.030 validation 0.126
# epoch 400 reconstruction 0.027 validation 0.132
# epoch 0 reconstruction 0.174 validation 0.180
# epoch 50 reconstruction 0.093 validation 0.096
# epoch 100 reconstruction 0.078 validation 0.081
# epoch 150 reconstruction 0.078 validation 0.080
# epoch 200 reconstruction 0.058 validation 0.092
# epoch 250 reconstruction 0.045 validation 0.110
# epoch 300 reconstruction 0.037 validation 0.121
# epoch 350 reconstruction 0.033 validation 0.129
# epoch 400 reconstruction 0.031 validation 0.134
# epoch 0 reconstruction 0.178 validation 0.170
# epoch 50 reconstruction 0.095 validation 0.096
# epoch 100 reconstruction 0.078 validation 0.081
# epoch 150 reconstruction 0.078 validation 0.080
# epoch 200 reconstruction 0.059 validation 0.092
# epoch 250 reconstruction 0.044 validation 0.109
# epoch 300 reconstruction 0.038 validation 0.120
# epoch 350 reconstruction 0.032 validation 0.130
# epoch 400 reconstruction 0.030 validation 0.134
# epoch 0 reconstruction 0.205 validation 0.201
# epoch 50 reconstruction 0.098 validation 0.100
# epoch 100 reconstruction 0.078 validation 0.081
# epoch 150 reconstruction 0.077 validation 0.080
# epoch 200 reconstruction 0.060 validation 0.090
# epoch 250 reconstruction 0.045 validation 0.104
# epoch 300 reconstruction 0.037 validation 0.117
# epoch 350 reconstruction 0.033 validation 0.123
# epoch 400 reconstruction 0.029 validation 0.130
# epoch 0 reconstruction 0.228 validation 0.215
# epoch 50 reconstruction 0.102 validation 0.101
# epoch 100 reconstruction 0.078 validation 0.080
# epoch 150 reconstruction 0.077 validation 0.079
# epoch 200 reconstruction 0.058 validation 0.091
# epoch 250 reconstruction 0.045 validation 0.106
# epoch 300 reconstruction 0.038 validation 0.116
# epoch 350 reconstruction 0.033 validation 0.123
# epoch 400 reconstruction 0.029 validation 0.128
# epoch 0 reconstruction 0.178 validation 0.182
# epoch 50 reconstruction 0.095 validation 0.097
# epoch 100 reconstruction 0.078 validation 0.081
# epoch 150 reconstruction 0.078 validation 0.080
# epoch 200 reconstruction 0.059 validation 0.094
# epoch 250 reconstruction 0.045 validation 0.108
# epoch 300 reconstruction 0.037 validation 0.121
# epoch 350 reconstruction 0.034 validation 0.128
# epoch 400 reconstruction 0.029 validation 0.139
# epoch 0 reconstruction 0.206 validation 0.202
# epoch 50 reconstruction 0.099 validation 0.100
# epoch 100 reconstruction 0.078 validation 0.080
# epoch 150 reconstruction 0.077 validation 0.080
# epoch 200 reconstruction 0.058 validation 0.094
# epoch 250 reconstruction 0.045 validation 0.111
# epoch 300 reconstruction 0.036 validation 0.121
# epoch 350 reconstruction 0.033 validation 0.127
# epoch 400 reconstruction 0.030 validation 0.134
# epoch 0 reconstruction 0.186 validation 0.191
# epoch 50 reconstruction 0.096 validation 0.100
# epoch 100 reconstruction 0.079 validation 0.081
# epoch 150 reconstruction 0.078 validation 0.081
# epoch 200 reconstruction 0.057 validation 0.094
# epoch 250 reconstruction 0.043 validation 0.109
# epoch 300 reconstruction 0.037 validation 0.121
# epoch 350 reconstruction 0.033 validation 0.128
# epoch 400 reconstruction 0.029 validation 0.137
# epoch 0 reconstruction 0.219 validation 0.259
# epoch 50 reconstruction 0.102 validation 0.110
# epoch 100 reconstruction 0.078 validation 0.081
# epoch 150 reconstruction 0.077 validation 0.080
# epoch 200 reconstruction 0.058 validation 0.093
# epoch 250 reconstruction 0.043 validation 0.108
# epoch 300 reconstruction 0.036 validation 0.122
# epoch 350 reconstruction 0.033 validation 0.128
# epoch 400 reconstruction 0.031 validation 0.132
# epoch 0 reconstruction 0.197 validation 0.209
# epoch 50 reconstruction 0.098 validation 0.103
# epoch 100 reconstruction 0.078 validation 0.082
# epoch 150 reconstruction 0.077 validation 0.081
# epoch 200 reconstruction 0.058 validation 0.094
# epoch 250 reconstruction 0.044 validation 0.109
# epoch 300 reconstruction 0.036 validation 0.120
# epoch 350 reconstruction 0.032 validation 0.129
# epoch 400 reconstruction 0.029 validation 0.135
# epoch 0 reconstruction 0.175 validation 0.189
# epoch 50 reconstruction 0.093 validation 0.096
# epoch 100 reconstruction 0.078 validation 0.080
# epoch 150 reconstruction 0.077 validation 0.081
# epoch 200 reconstruction 0.060 validation 0.090
# epoch 250 reconstruction 0.047 validation 0.103
# epoch 300 reconstruction 0.041 validation 0.115
# epoch 350 reconstruction 0.036 validation 0.123
# epoch 400 reconstruction 0.034 validation 0.130
# epoch 0 reconstruction 0.205 validation 0.198
# epoch 50 reconstruction 0.098 validation 0.099
# epoch 100 reconstruction 0.078 validation 0.080
# epoch 150 reconstruction 0.077 validation 0.080
# epoch 200 reconstruction 0.058 validation 0.089
# epoch 250 reconstruction 0.045 validation 0.103
# epoch 300 reconstruction 0.038 validation 0.112
# epoch 350 reconstruction 0.033 validation 0.121
# epoch 400 reconstruction 0.031 validation 0.127
# epoch 0 reconstruction 0.221 validation 0.226
# epoch 50 reconstruction 0.099 validation 0.102
# epoch 100 reconstruction 0.078 validation 0.081
# epoch 150 reconstruction 0.077 validation 0.080
# epoch 200 reconstruction 0.057 validation 0.092
# epoch 250 reconstruction 0.042 validation 0.109
# epoch 300 reconstruction 0.035 validation 0.120
# epoch 350 reconstruction 0.031 validation 0.126
# epoch 400 reconstruction 0.028 validation 0.134
# epoch 0 reconstruction 0.204 validation 0.184
# epoch 50 reconstruction 0.097 validation 0.097
# epoch 100 reconstruction 0.078 validation 0.081
# epoch 150 reconstruction 0.078 validation 0.081
# epoch 200 reconstruction 0.059 validation 0.092
# epoch 250 reconstruction 0.045 validation 0.106
# epoch 300 reconstruction 0.038 validation 0.116
# epoch 350 reconstruction 0.034 validation 0.125
# epoch 400 reconstruction 0.032 validation 0.131
# epoch 0 reconstruction 0.193 validation 0.205
# epoch 50 reconstruction 0.096 validation 0.099
# epoch 100 reconstruction 0.078 validation 0.080
# epoch 150 reconstruction 0.077 validation 0.079
# epoch 200 reconstruction 0.058 validation 0.093
# epoch 250 reconstruction 0.044 validation 0.106
# epoch 300 reconstruction 0.037 validation 0.116
# epoch 350 reconstruction 0.033 validation 0.126
# epoch 400 reconstruction 0.029 validation 0.130
# epoch 0 reconstruction 0.222 validation 0.208
# epoch 50 reconstruction 0.100 validation 0.100
# epoch 100 reconstruction 0.077 validation 0.080
# epoch 150 reconstruction 0.076 validation 0.079
# epoch 200 reconstruction 0.058 validation 0.089
# epoch 250 reconstruction 0.043 validation 0.105
# epoch 300 reconstruction 0.037 validation 0.116
# epoch 350 reconstruction 0.031 validation 0.124
# epoch 400 reconstruction 0.031 validation 0.129
# epoch 0 reconstruction 0.237 validation 0.231
# epoch 50 reconstruction 0.103 validation 0.104
# epoch 100 reconstruction 0.077 validation 0.080
# epoch 150 reconstruction 0.076 validation 0.079
# epoch 200 reconstruction 0.056 validation 0.092
# epoch 250 reconstruction 0.042 validation 0.107
# epoch 300 reconstruction 0.035 validation 0.117
# epoch 350 reconstruction 0.031 validation 0.126
# epoch 400 reconstruction 0.028 validation 0.131
# epoch 0 reconstruction 0.271 validation 0.273
# epoch 50 reconstruction 0.108 validation 0.110
# epoch 100 reconstruction 0.077 validation 0.079
# epoch 150 reconstruction 0.075 validation 0.078
# epoch 200 reconstruction 0.056 validation 0.091
# epoch 250 reconstruction 0.043 validation 0.106
# epoch 300 reconstruction 0.036 validation 0.116
# epoch 350 reconstruction 0.032 validation 0.122
# epoch 400 reconstruction 0.028 validation 0.127
# epoch 0 reconstruction 0.256 validation 0.233
# epoch 50 reconstruction 0.105 validation 0.104
# epoch 100 reconstruction 0.077 validation 0.080
# epoch 150 reconstruction 0.075 validation 0.078
# epoch 200 reconstruction 0.057 validation 0.089
# epoch 250 reconstruction 0.043 validation 0.103
# epoch 300 reconstruction 0.036 validation 0.111
# epoch 350 reconstruction 0.031 validation 0.120
# epoch 400 reconstruction 0.028 validation 0.124
# epoch 0 reconstruction 0.194 validation 0.190
# epoch 50 reconstruction 0.095 validation 0.096
# epoch 100 reconstruction 0.077 validation 0.080
# epoch 150 reconstruction 0.077 validation 0.080
# epoch 200 reconstruction 0.057 validation 0.092
# epoch 250 reconstruction 0.042 validation 0.106
# epoch 300 reconstruction 0.035 validation 0.117
# epoch 350 reconstruction 0.032 validation 0.126
# epoch 400 reconstruction 0.029 validation 0.132
# epoch 0 reconstruction 0.187 validation 0.185
# epoch 50 reconstruction 0.096 validation 0.097
# epoch 100 reconstruction 0.078 validation 0.081
# epoch 150 reconstruction 0.078 validation 0.080
# epoch 200 reconstruction 0.058 validation 0.091
# epoch 250 reconstruction 0.043 validation 0.105
# epoch 300 reconstruction 0.037 validation 0.114
# epoch 350 reconstruction 0.033 validation 0.122
# epoch 400 reconstruction 0.030 validation 0.128
# epoch 0 reconstruction 0.205 validation 0.196
# epoch 50 reconstruction 0.098 validation 0.099
# epoch 100 reconstruction 0.078 validation 0.080
# epoch 150 reconstruction 0.077 validation 0.079
# epoch 200 reconstruction 0.059 validation 0.090
# epoch 250 reconstruction 0.044 validation 0.103
# epoch 300 reconstruction 0.036 validation 0.113
# epoch 350 reconstruction 0.033 validation 0.121
# epoch 400 reconstruction 0.030 validation 0.126
# epoch 0 reconstruction 0.193 validation 0.198
# epoch 50 reconstruction 0.096 validation 0.099
# epoch 100 reconstruction 0.078 validation 0.080
# epoch 150 reconstruction 0.077 validation 0.080
# epoch 200 reconstruction 0.057 validation 0.091
# epoch 250 reconstruction 0.042 validation 0.108
# epoch 300 reconstruction 0.035 validation 0.117
# epoch 350 reconstruction 0.032 validation 0.122
# epoch 400 reconstruction 0.029 validation 0.128
# epoch 0 reconstruction 0.176 validation 0.174
# epoch 50 reconstruction 0.094 validation 0.095
# epoch 100 reconstruction 0.078 validation 0.081
# epoch 150 reconstruction 0.078 validation 0.081
# epoch 200 reconstruction 0.061 validation 0.091
# epoch 250 reconstruction 0.046 validation 0.105
# epoch 300 reconstruction 0.040 validation 0.117
# epoch 350 reconstruction 0.035 validation 0.126
# epoch 400 reconstruction 0.032 validation 0.132
# epoch 0 reconstruction 0.168 validation 0.167
# epoch 50 reconstruction 0.094 validation 0.096
# epoch 100 reconstruction 0.078 validation 0.081
# epoch 150 reconstruction 0.078 validation 0.081
# epoch 200 reconstruction 0.061 validation 0.090
# epoch 250 reconstruction 0.048 validation 0.106
# epoch 300 reconstruction 0.039 validation 0.119
# epoch 350 reconstruction 0.035 validation 0.128
# epoch 400 reconstruction 0.032 validation 0.133
# epoch 0 reconstruction 0.193 validation 0.195
# epoch 50 reconstruction 0.096 validation 0.098
# epoch 100 reconstruction 0.078 validation 0.080
# epoch 150 reconstruction 0.077 validation 0.079
# epoch 200 reconstruction 0.060 validation 0.089
# epoch 250 reconstruction 0.045 validation 0.104
# epoch 300 reconstruction 0.038 validation 0.114
# epoch 350 reconstruction 0.035 validation 0.123
# epoch 400 reconstruction 0.030 validation 0.129
# epoch 0 reconstruction 0.193 validation 0.186
# epoch 50 reconstruction 0.097 validation 0.098
# epoch 100 reconstruction 0.078 validation 0.081
# epoch 150 reconstruction 0.078 validation 0.080
# epoch 200 reconstruction 0.057 validation 0.090
# epoch 250 reconstruction 0.043 validation 0.105
# epoch 300 reconstruction 0.036 validation 0.115
# epoch 350 reconstruction 0.032 validation 0.123
# epoch 400 reconstruction 0.030 validation 0.129
# epoch 0 reconstruction 0.178 validation 0.169
# epoch 50 reconstruction 0.094 validation 0.095
# epoch 100 reconstruction 0.078 validation 0.081
# epoch 150 reconstruction 0.078 validation 0.080
# epoch 200 reconstruction 0.059 validation 0.093
# epoch 250 reconstruction 0.044 validation 0.107
# epoch 300 reconstruction 0.037 validation 0.116
# epoch 350 reconstruction 0.033 validation 0.125
# epoch 400 reconstruction 0.030 validation 0.131
# epoch 0 reconstruction 0.195 validation 0.189
# epoch 50 reconstruction 0.098 validation 0.099
# epoch 100 reconstruction 0.077 validation 0.080
# epoch 150 reconstruction 0.076 validation 0.079
# epoch 200 reconstruction 0.056 validation 0.091
# epoch 250 reconstruction 0.043 validation 0.107
# epoch 300 reconstruction 0.036 validation 0.118
# epoch 350 reconstruction 0.031 validation 0.126
# epoch 400 reconstruction 0.028 validation 0.134
# epoch 0 reconstruction 0.203 validation 0.206
# epoch 50 reconstruction 0.098 validation 0.102
# epoch 100 reconstruction 0.076 validation 0.080
# epoch 150 reconstruction 0.075 validation 0.079
# epoch 200 reconstruction 0.058 validation 0.091
# epoch 250 reconstruction 0.044 validation 0.103
# epoch 300 reconstruction 0.037 validation 0.112
# epoch 350 reconstruction 0.033 validation 0.119
# epoch 400 reconstruction 0.030 validation 0.124
# epoch 0 reconstruction 0.190 validation 0.180
# epoch 50 reconstruction 0.095 validation 0.094
# epoch 100 reconstruction 0.076 validation 0.078
# epoch 150 reconstruction 0.076 validation 0.079
# epoch 200 reconstruction 0.055 validation 0.092
# epoch 250 reconstruction 0.041 validation 0.108
# epoch 300 reconstruction 0.034 validation 0.118
# epoch 350 reconstruction 0.032 validation 0.125
# epoch 400 reconstruction 0.028 validation 0.132
# epoch 0 reconstruction 0.199 validation 0.193
# epoch 50 reconstruction 0.098 validation 0.098
# epoch 100 reconstruction 0.077 validation 0.079
# epoch 150 reconstruction 0.076 validation 0.078
# epoch 200 reconstruction 0.057 validation 0.090
# epoch 250 reconstruction 0.045 validation 0.106
# epoch 300 reconstruction 0.037 validation 0.115
# epoch 350 reconstruction 0.034 validation 0.122
# epoch 400 reconstruction 0.032 validation 0.127
# epoch 0 reconstruction 0.236 validation 0.229
# epoch 50 reconstruction 0.101 validation 0.102
# epoch 100 reconstruction 0.076 validation 0.078
# epoch 150 reconstruction 0.075 validation 0.077
# epoch 200 reconstruction 0.055 validation 0.090
# epoch 250 reconstruction 0.041 validation 0.109
# epoch 300 reconstruction 0.033 validation 0.119
# epoch 350 reconstruction 0.031 validation 0.127
# epoch 400 reconstruction 0.027 validation 0.135
# epoch 0 reconstruction 0.238 validation 0.261
# epoch 50 reconstruction 0.103 validation 0.108
# epoch 100 reconstruction 0.076 validation 0.078
# epoch 150 reconstruction 0.074 validation 0.077
# epoch 200 reconstruction 0.057 validation 0.088
# epoch 250 reconstruction 0.044 validation 0.103
# epoch 300 reconstruction 0.037 validation 0.115
# epoch 350 reconstruction 0.033 validation 0.124
# ...
# epoch 350 reconstruction 0.030 validation 0.126
# epoch 400 reconstruction 0.028 validation 0.131
# epoch 0 reconstruction 0.305 validation 0.326
# epoch 50 reconstruction 0.112 validation 0.117
# epoch 100 reconstruction 0.077 validation 0.079
# epoch 150 reconstruction 0.074 validation 0.077
# epoch 200 reconstruction 0.055 validation 0.088
# epoch 250 reconstruction 0.040 validation 0.104
# epoch 300 reconstruction 0.036 validation 0.117
# epoch 350 reconstruction 0.030 validation 0.125
# epoch 400 reconstruction 0.027 validation 0.132
# epoch 0 reconstruction 0.215 validation 0.210
# epoch 50 reconstruction 0.098 validation 0.100
# epoch 100 reconstruction 0.077 validation 0.080
# epoch 150 reconstruction 0.077 validation 0.079
# epoch 200 reconstruction 0.056 validation 0.093
# epoch 250 reconstruction 0.043 validation 0.109
# epoch 300 reconstruction 0.036 validation 0.121
# epoch 350 reconstruction 0.031 validation 0.128
# epoch 400 reconstruction 0.029 validation 0.134
# epoch 0 reconstruction 0.233 validation 0.232
# epoch 50 reconstruction 0.100 validation 0.103
# epoch 100 reconstruction 0.076 validation 0.080
# epoch 150 reconstruction 0.075 validation 0.079
# epoch 200 reconstruction 0.056 validation 0.092
# epoch 250 reconstruction 0.041 validation 0.105
# epoch 300 reconstruction 0.035 validation 0.115
# epoch 350 reconstruction 0.031 validation 0.124
# epoch 400 reconstruction 0.029 validation 0.132
# epoch 0 reconstruction 0.216 validation 0.233
# epoch 50 reconstruction 0.099 validation 0.103
# epoch 100 reconstruction 0.077 validation 0.080
# epoch 150 reconstruction 0.075 validation 0.079
# epoch 200 reconstruction 0.055 validation 0.093
# epoch 250 reconstruction 0.041 validation 0.111
# epoch 300 reconstruction 0.035 validation 0.123
# epoch 350 reconstruction 0.031 validation 0.130
# epoch 400 reconstruction 0.029 validation 0.135
# epoch 0 reconstruction 0.220 validation 0.234
# epoch 50 reconstruction 0.100 validation 0.104
# epoch 100 reconstruction 0.077 validation 0.080
# epoch 150 reconstruction 0.076 validation 0.079
# epoch 200 reconstruction 0.057 validation 0.092
# epoch 250 reconstruction 0.044 validation 0.108
# epoch 300 reconstruction 0.037 validation 0.120
# epoch 350 reconstruction 0.031 validation 0.129
# epoch 400 reconstruction 0.030 validation 0.134
# epoch 0 reconstruction 0.275 validation 0.290
# epoch 50 reconstruction 0.105 validation 0.111
# epoch 100 reconstruction 0.076 validation 0.080
# epoch 150 reconstruction 0.075 validation 0.078
# epoch 200 reconstruction 0.058 validation 0.087
# epoch 250 reconstruction 0.045 validation 0.103
# epoch 300 reconstruction 0.038 validation 0.115
# epoch 350 reconstruction 0.034 validation 0.122
# epoch 400 reconstruction 0.030 validation 0.128
# epoch 0 reconstruction 0.266 validation 0.327
# epoch 50 reconstruction 0.107 validation 0.118
# epoch 100 reconstruction 0.076 validation 0.079
# epoch 150 reconstruction 0.075 validation 0.078
# epoch 200 reconstruction 0.055 validation 0.090
# epoch 250 reconstruction 0.041 validation 0.107
# epoch 300 reconstruction 0.034 validation 0.119
# epoch 350 reconstruction 0.031 validation 0.126
# epoch 400 reconstruction 0.028 validation 0.134
# epoch 0 reconstruction 0.296 validation 0.273
# epoch 50 reconstruction 0.109 validation 0.108
# epoch 100 reconstruction 0.076 validation 0.079
# epoch 150 reconstruction 0.074 validation 0.078
# epoch 200 reconstruction 0.056 validation 0.089
# epoch 250 reconstruction 0.042 validation 0.104
# epoch 300 reconstruction 0.037 validation 0.114
# epoch 350 reconstruction 0.031 validation 0.122
# epoch 400 reconstruction 0.030 validation 0.129
# epoch 0 reconstruction 0.282 validation 0.314
# epoch 50 reconstruction 0.108 validation 0.114
# epoch 100 reconstruction 0.076 validation 0.079
# epoch 150 reconstruction 0.074 validation 0.077
# epoch 200 reconstruction 0.057 validation 0.091
# epoch 250 reconstruction 0.044 validation 0.108
# epoch 300 reconstruction 0.037 validation 0.116
# epoch 350 reconstruction 0.032 validation 0.124
# epoch 400 reconstruction 0.032 validation 0.131
# epoch 0 reconstruction 0.279 validation 0.261
# epoch 50 reconstruction 0.106 validation 0.105
# epoch 100 reconstruction 0.076 validation 0.079
# epoch 150 reconstruction 0.074 validation 0.078
# epoch 200 reconstruction 0.054 validation 0.092
# epoch 250 reconstruction 0.042 validation 0.107
# epoch 300 reconstruction 0.035 validation 0.120
# epoch 350 reconstruction 0.031 validation 0.126
# epoch 400 reconstruction 0.027 validation 0.134
# epoch 0 reconstruction 0.248 validation 0.238
# epoch 50 reconstruction 0.102 validation 0.103
# epoch 100 reconstruction 0.076 validation 0.079
# epoch 150 reconstruction 0.075 validation 0.078
# epoch 200 reconstruction 0.056 validation 0.090
# epoch 250 reconstruction 0.042 validation 0.108
# epoch 300 reconstruction 0.035 validation 0.121
# epoch 350 reconstruction 0.030 validation 0.129
# epoch 400 reconstruction 0.028 validation 0.135
# epoch 0 reconstruction 0.248 validation 0.248
# epoch 50 reconstruction 0.102 validation 0.103
# epoch 100 reconstruction 0.076 validation 0.079
# epoch 150 reconstruction 0.076 validation 0.078
# epoch 200 reconstruction 0.056 validation 0.092
# epoch 250 reconstruction 0.042 validation 0.110
# epoch 300 reconstruction 0.036 validation 0.119
# epoch 350 reconstruction 0.031 validation 0.129
# epoch 400 reconstruction 0.029 validation 0.136
# epoch 0 reconstruction 0.305 validation 0.309
# epoch 50 reconstruction 0.107 validation 0.111
# epoch 100 reconstruction 0.076 validation 0.078
# epoch 150 reconstruction 0.074 validation 0.076
# epoch 200 reconstruction 0.055 validation 0.091
# epoch 250 reconstruction 0.043 validation 0.108
# epoch 300 reconstruction 0.036 validation 0.118
# epoch 350 reconstruction 0.032 validation 0.127
# epoch 400 reconstruction 0.029 validation 0.133
# epoch 0 reconstruction 0.296 validation 0.362
# epoch 50 reconstruction 0.110 validation 0.122
# epoch 100 reconstruction 0.076 validation 0.079
# epoch 150 reconstruction 0.074 validation 0.076
# epoch 200 reconstruction 0.055 validation 0.089
# epoch 250 reconstruction 0.041 validation 0.108
# epoch 300 reconstruction 0.034 validation 0.120
# epoch 350 reconstruction 0.031 validation 0.130
# epoch 400 reconstruction 0.029 validation 0.138
# epoch 0 reconstruction 0.337 validation 0.319
# epoch 50 reconstruction 0.115 validation 0.115
# epoch 100 reconstruction 0.076 validation 0.079
# epoch 150 reconstruction 0.073 validation 0.076
# epoch 200 reconstruction 0.054 validation 0.090
# epoch 250 reconstruction 0.041 validation 0.107
# epoch 300 reconstruction 0.034 validation 0.118
# epoch 350 reconstruction 0.030 validation 0.126
# epoch 400 reconstruction 0.028 validation 0.132
# epoch 0 reconstruction 0.314 validation 0.352
# epoch 50 reconstruction 0.112 validation 0.119
# epoch 100 reconstruction 0.076 validation 0.079
# epoch 150 reconstruction 0.073 validation 0.075
# epoch 200 reconstruction 0.053 validation 0.091
# epoch 250 reconstruction 0.040 validation 0.110
# epoch 300 reconstruction 0.034 validation 0.121
# epoch 350 reconstruction 0.031 validation 0.128
# epoch 400 reconstruction 0.028 validation 0.137
# epoch 0 reconstruction 0.277 validation 0.278
# epoch 50 reconstruction 0.106 validation 0.109
# epoch 100 reconstruction 0.076 validation 0.079
# epoch 150 reconstruction 0.074 validation 0.077
# epoch 200 reconstruction 0.055 validation 0.090
# epoch 250 reconstruction 0.043 validation 0.103
# epoch 300 reconstruction 0.036 validation 0.114
# epoch 350 reconstruction 0.032 validation 0.121
# epoch 400 reconstruction 0.030 validation 0.125
# epoch 0 reconstruction 0.281 validation 0.293
# epoch 50 reconstruction 0.106 validation 0.110
# epoch 100 reconstruction 0.076 validation 0.080
# epoch 150 reconstruction 0.074 validation 0.078
# epoch 200 reconstruction 0.055 validation 0.090
# epoch 250 reconstruction 0.041 validation 0.107
# epoch 300 reconstruction 0.034 validation 0.116
# epoch 350 reconstruction 0.030 validation 0.125
# epoch 400 reconstruction 0.029 validation 0.129
# epoch 0 reconstruction 0.343 validation 0.354
# epoch 50 reconstruction 0.112 validation 0.116
# epoch 100 reconstruction 0.076 validation 0.079
# epoch 150 reconstruction 0.073 validation 0.076
# epoch 200 reconstruction 0.055 validation 0.087
# epoch 250 reconstruction 0.042 validation 0.103
# epoch 300 reconstruction 0.036 validation 0.113
# epoch 350 reconstruction 0.033 validation 0.121
# epoch 400 reconstruction 0.030 validation 0.128
# epoch 0 reconstruction 0.355 validation 0.387
# epoch 50 reconstruction 0.119 validation 0.125
# epoch 100 reconstruction 0.076 validation 0.080
# epoch 150 reconstruction 0.073 validation 0.076
# epoch 200 reconstruction 0.054 validation 0.088
# epoch 250 reconstruction 0.041 validation 0.103
# epoch 300 reconstruction 0.035 validation 0.112
# epoch 350 reconstruction 0.031 validation 0.121
# epoch 400 reconstruction 0.028 validation 0.127
# epoch 0 reconstruction 0.392 validation 0.331
# epoch 50 reconstruction 0.119 validation 0.116
# epoch 100 reconstruction 0.076 validation 0.079
# epoch 150 reconstruction 0.073 validation 0.076
# epoch 200 reconstruction 0.053 validation 0.087
# epoch 250 reconstruction 0.040 validation 0.102
# epoch 300 reconstruction 0.036 validation 0.109
# epoch 350 reconstruction 0.032 validation 0.115
# epoch 400 reconstruction 0.028 validation 0.121
# epoch 0 reconstruction 0.342 validation 0.396
# epoch 50 reconstruction 0.115 validation 0.123
# epoch 100 reconstruction 0.076 validation 0.078
# epoch 150 reconstruction 0.073 validation 0.076
# epoch 200 reconstruction 0.054 validation 0.090
# epoch 250 reconstruction 0.043 validation 0.105
# epoch 300 reconstruction 0.036 validation 0.117
# epoch 350 reconstruction 0.033 validation 0.122
# epoch 400 reconstruction 0.030 validation 0.129
# epoch 0 reconstruction 0.272 validation 0.265
# epoch 50 reconstruction 0.106 validation 0.108
# epoch 100 reconstruction 0.077 validation 0.079
# epoch 150 reconstruction 0.075 validation 0.078
# epoch 200 reconstruction 0.057 validation 0.089
# epoch 250 reconstruction 0.044 validation 0.105
# epoch 300 reconstruction 0.039 validation 0.115
# epoch 350 reconstruction 0.033 validation 0.122
# epoch 400 reconstruction 0.031 validation 0.127
# epoch 0 reconstruction 0.308 validation 0.337
# epoch 50 reconstruction 0.108 validation 0.115
# epoch 100 reconstruction 0.076 validation 0.079
# epoch 150 reconstruction 0.074 validation 0.077
# epoch 200 reconstruction 0.054 validation 0.091
# epoch 250 reconstruction 0.042 validation 0.109
# epoch 300 reconstruction 0.035 validation 0.121
# epoch 350 reconstruction 0.032 validation 0.127
# epoch 400 reconstruction 0.029 validation 0.133
# epoch 0 reconstruction 0.313 validation 0.334
# epoch 50 reconstruction 0.112 validation 0.116
# epoch 100 reconstruction 0.076 validation 0.078
# epoch 150 reconstruction 0.073 validation 0.076
# epoch 200 reconstruction 0.052 validation 0.091
# epoch 250 reconstruction 0.039 validation 0.109
# epoch 300 reconstruction 0.033 validation 0.121
# epoch 350 reconstruction 0.029 validation 0.130
# epoch 400 reconstruction 0.026 validation 0.137
# epoch 0 reconstruction 0.336 validation 0.296
# epoch 50 reconstruction 0.114 validation 0.112
# epoch 100 reconstruction 0.076 validation 0.078
# epoch 150 reconstruction 0.073 validation 0.076
# epoch 200 reconstruction 0.054 validation 0.089
# epoch 250 reconstruction 0.041 validation 0.104
# epoch 300 reconstruction 0.035 validation 0.114
# epoch 350 reconstruction 0.031 validation 0.123
# epoch 400 reconstruction 0.029 validation 0.129
# epoch 0 reconstruction 0.343 validation 0.374
# epoch 50 reconstruction 0.116 validation 0.120
# epoch 100 reconstruction 0.076 validation 0.078
# epoch 150 reconstruction 0.073 validation 0.076
# epoch 200 reconstruction 0.054 validation 0.090
# epoch 250 reconstruction 0.040 validation 0.107
# epoch 300 reconstruction 0.033 validation 0.117
# epoch 350 reconstruction 0.030 validation 0.124
# epoch 400 reconstruction 0.026 validation 0.129
# epoch 0 reconstruction 0.301 validation 0.323
# epoch 50 reconstruction 0.106 validation 0.111
# epoch 100 reconstruction 0.075 validation 0.078
# epoch 150 reconstruction 0.073 validation 0.076
# epoch 200 reconstruction 0.055 validation 0.089
# epoch 250 reconstruction 0.043 validation 0.102
# epoch 300 reconstruction 0.035 validation 0.111
# epoch 350 reconstruction 0.031 validation 0.119
# epoch 400 reconstruction 0.029 validation 0.125
# epoch 0 reconstruction 0.315 validation 0.358
# epoch 50 reconstruction 0.112 validation 0.122
# epoch 100 reconstruction 0.076 validation 0.079
# epoch 150 reconstruction 0.074 validation 0.076
# epoch 200 reconstruction 0.053 validation 0.090
# epoch 250 reconstruction 0.040 validation 0.108
# epoch 300 reconstruction 0.033 validation 0.119
# epoch 350 reconstruction 0.030 validation 0.126
# epoch 400 reconstruction 0.027 validation 0.132
# epoch 0 reconstruction 0.369 validation 0.358
# epoch 50 reconstruction 0.118 validation 0.120
# epoch 100 reconstruction 0.076 validation 0.079
# epoch 150 reconstruction 0.073 validation 0.077
# epoch 200 reconstruction 0.054 validation 0.088
# epoch 250 reconstruction 0.042 validation 0.107
# epoch 300 reconstruction 0.035 validation 0.120
# epoch 350 reconstruction 0.031 validation 0.128
# epoch 400 reconstruction 0.028 validation 0.136
# epoch 0 reconstruction 0.340 validation 0.397
# epoch 50 reconstruction 0.115 validation 0.124
# epoch 100 reconstruction 0.076 validation 0.079
# epoch 150 reconstruction 0.073 validation 0.076
# epoch 200 reconstruction 0.054 validation 0.089
# epoch 250 reconstruction 0.041 validation 0.108
# epoch 300 reconstruction 0.035 validation 0.120
# epoch 350 reconstruction 0.031 validation 0.127
# epoch 400 reconstruction 0.027 validation 0.133
# epoch 0 reconstruction 0.385 validation 0.463
# epoch 50 reconstruction 0.120 validation 0.133
# epoch 100 reconstruction 0.076 validation 0.079
# epoch 150 reconstruction 0.072 validation 0.074
# epoch 200 reconstruction 0.054 validation 0.087
# epoch 250 reconstruction 0.041 validation 0.103
# epoch 300 reconstruction 0.034 validation 0.116
# epoch 350 reconstruction 0.031 validation 0.122
# epoch 400 reconstruction 0.028 validation 0.129
# epoch 0 reconstruction 0.411 validation 0.375
# epoch 50 reconstruction 0.121 validation 0.122
# epoch 100 reconstruction 0.076 validation 0.078
# epoch 150 reconstruction 0.072 validation 0.075
# epoch 200 reconstruction 0.050 validation 0.089
# epoch 250 reconstruction 0.038 validation 0.109
# epoch 300 reconstruction 0.031 validation 0.121
# epoch 350 reconstruction 0.027 validation 0.127
# epoch 400 reconstruction 0.025 validation 0.134
# epoch 0 reconstruction 0.393 validation 0.452
# epoch 50 reconstruction 0.121 validation 0.130
# epoch 100 reconstruction 0.076 validation 0.078
# epoch 150 reconstruction 0.072 validation 0.074
# epoch 200 reconstruction 0.052 validation 0.089
# epoch 250 reconstruction 0.038 validation 0.109
# epoch 300 reconstruction 0.034 validation 0.119
# epoch 350 reconstruction 0.029 validation 0.128
# epoch 400 reconstruction 0.026 validation 0.135
# epoch 0 reconstruction 0.410 validation 0.425
# epoch 50 reconstruction 0.123 validation 0.128
# epoch 100 reconstruction 0.076 validation 0.078
# epoch 150 reconstruction 0.072 validation 0.075
# epoch 200 reconstruction 0.050 validation 0.091
# epoch 250 reconstruction 0.038 validation 0.109
# epoch 300 reconstruction 0.031 validation 0.117
# epoch 350 reconstruction 0.027 validation 0.126
# epoch 400 reconstruction 0.024 validation 0.132
# epoch 0 reconstruction 0.376 validation 0.464
# epoch 50 reconstruction 0.121 validation 0.134
# epoch 100 reconstruction 0.076 validation 0.078
# epoch 150 reconstruction 0.072 validation 0.074
# epoch 200 reconstruction 0.053 validation 0.089
# epoch 250 reconstruction 0.040 validation 0.107
# epoch 300 reconstruction 0.034 validation 0.119
# epoch 350 reconstruction 0.031 validation 0.126
# epoch 400 reconstruction 0.029 validation 0.132
# epoch 0 reconstruction 0.441 validation 0.442
# epoch 50 reconstruction 0.130 validation 0.133
# epoch 100 reconstruction 0.077 validation 0.079
# epoch 150 reconstruction 0.072 validation 0.075
# epoch 200 reconstruction 0.052 validation 0.089
# epoch 250 reconstruction 0.040 validation 0.103
# epoch 300 reconstruction 0.035 validation 0.113
# epoch 350 reconstruction 0.031 validation 0.119
# epoch 400 reconstruction 0.028 validation 0.125

# %%
loss_tests = []
for key in RE_model.loss_tests.keys():
    loss_tests.append(np.mean(RE_model.loss_tests[key][-5::]))
    
plt.hist(loss_tests, bins=20)
# Out:
# (array([  1.,   0.,   0.,   5.,  12.,  41.,  57.,  98., 120., 109., 116.,
#          81.,  56.,  42.,  19.,  13.,   8.,   1.,   0.,   1.]),
#  array([0.1150317 , 0.11674449, 0.11845729, 0.12017008, 0.12188287,
#         0.12359566, 0.12530845, 0.12702124, 0.12873403, 0.13044682,
#         0.13215961, 0.1338724 , 0.13558519, 0.13729798, 0.13901077,
#         0.14072356, 0.14243635, 0.14414914, 0.14586193, 0.14757472,
#         0.14928751]),
#  <BarContainer object of 20 artists>)
